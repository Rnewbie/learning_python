# %%
type("Saw")
# Out:
# str

# %%
type(23)
# Out:
# int

# %%
type(23.22)
# Out:
# float

# %%
x = "Saw"

# %%
x
# Out:
# 'Saw'

# %%
type(x)
# Out:
# str

# %%
import pandas as pd

# %%
data = pd.read_csv("https://raw.githubusercontent.com/Rnewbie/OliFP/master/AAC.csv")

# %%
data
# Out:
#             A         R         N         D         C         E         Q  \
# 0    0.037815  0.025210  0.054622  0.075630  0.008403  0.067227  0.033613
# 1    0.033613  0.025210  0.054622  0.075630  0.012605  0.067227  0.033613
# 2    0.033613  0.025210  0.054622  0.075630  0.008403  0.067227  0.033613
# 3    0.033613  0.025210  0.054622  0.075630  0.008403  0.067227  0.033613
# 4    0.033613  0.025210  0.054622  0.075630  0.008403  0.067227  0.033613
# 5    0.033613  0.025210  0.054622  0.075630  0.008403  0.067227  0.033613
# 6    0.037815  0.029412  0.054622  0.075630  0.008403  0.067227  0.029412
# 7    0.039648  0.030837  0.057269  0.074890  0.008811  0.066079  0.030837
# 8    0.033613  0.029412  0.054622  0.075630  0.008403  0.067227  0.029412
# 9    0.057269  0.052863  0.035242  0.044053  0.030837  0.079295  0.017621
# 10   0.036290  0.040323  0.052419  0.068548  0.008065  0.060484  0.028226
# 11   0.060606  0.047619  0.034632  0.043290  0.025974  0.077922  0.017316
# ...

# %%
data.loc[1:10, 'E']
# Out:
# 1     0.067227
# 2     0.067227
# 3     0.067227
# 4     0.067227
# 5     0.067227
# 6     0.067227
# 7     0.066079
# 8     0.067227
# 9     0.079295
# 10    0.060484
# Name: E, dtype: float64

# %%
data.shape
# Out:
# (397, 20)

# %%
type(soe)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-03aef1a549a0> in <module>()
# ----> 1 type(soe)
#
# NameError: name 'soe' is not defined

# %%
type("soe")
# Out:
# str

# %%
def print_something():
    print 'I am so good'
    print 'I am so good'

# %%
print_something()
# Out:
# I am so good
# I am so good

# %%
def print_again():
    print_something()
    print_something()

# %%
print_again()
# Out:
# I am so good
# I am so good
# I am so good
# I am so good
